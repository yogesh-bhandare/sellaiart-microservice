# %%
import pathlib

NBS_DIR = pathlib.Path().resolve()
REPO_DIR = NBS_DIR.parent
DATA_DIR = REPO_DIR / "data"
GENERATED_DIR = DATA_DIR / "generated"
GENERATED_DIR.mkdir(exist_ok=True, parents=True)
REFERENCES_DIR = DATA_DIR / "references"
REFERENCES_DIR.mkdir(exist_ok=True, parents=True)

# %%
from decouple import config

REPLICATE_API_TOKEN = config("REPLICATE_API_TOKEN", default="")
REPLICATE_MODEL = config("REPLICATE_MODEL", default="yogesh-bhandare/sellaiart-yogesh-v1")
REPLICATE_MODEL_VERSION = config("REPLICATE_MODEL_VERSION", default="4bc2a39fa73d29cd531c57ad4f56bede13378ce3da2f6f517684b0b61bd192d7")

# %%
from replicate.client import Client

replicate_client = Client(api_token=REPLICATE_API_TOKEN)

# %%
reference_image_path = REFERENCES_DIR / "spider-man.webp"
image = open(reference_image_path, 'rb')

# %%
model = f"{REPLICATE_MODEL}:{REPLICATE_MODEL_VERSION}"
prompt = "a photo of TOK adult man dressed up as spider-man"

responses = replicate_client.run(
    model,
    input={
        "image": image,
        "model": "dev",
        "prompt": prompt,
        "num_outputs": 4,
        "output_format": "jpg",
    }
)
image.close()
# Out:
# ---------------------------------------------------------------------------
# ReplicateError                            Traceback (most recent call last)
# Cell In[11], line 4
#       1 model = f"{REPLICATE_MODEL}:{REPLICATE_MODEL_VERSION}"
#       2 prompt = "a photo of TOK adult man dressed up for a professional photo shoot"
# ----> 4 responses = replicate_client.run(
#       5     model,
#       6     input={
#       7         "model": "dev",
#       8         "prompt": prompt,
#       9         "num_outputs": 4,
#      10         "output_format": "jpg",
#      11     }
#      12 )
#      13 print(responses)
#
# File d:\Resume-Projects\sellaiart-microservice\.venv\Lib\site-packages\replicate\client.py:175, in Client.run(self, ref, input, use_file_output, **params)
#     163 def run(
#     164     self,
#     165     ref: str,
#    (...)
#     169     **params: Unpack["Predictions.CreatePredictionParams"],
#     170 ) -> Union[Any, Iterator[Any]]:  # noqa: ANN401
#     171     """
#     172     Run a model and wait for its output.
#     173     """
# --> 175     return run(self, ref, input, use_file_output=use_file_output, **params)
#
# File d:\Resume-Projects\sellaiart-microservice\.venv\Lib\site-packages\replicate\run.py:46, in run(client, ref, input, use_file_output, **params)
#      43 version, owner, name, version_id = identifier._resolve(ref)
#      45 if version_id is not None:
# ---> 46     prediction = client.predictions.create(
#      47         version=version_id, input=input or {}, **params
#      48     )
#      49 elif owner and name:
#      50     prediction = client.models.predictions.create(
#      51         model=(owner, name), input=input or {}, **params
#      52     )
#
# File d:\Resume-Projects\sellaiart-microservice\.venv\Lib\site-packages\replicate\prediction.py:497, in Predictions.create(self, model, version, deployment, input, *args, **params)
#     491 body = _create_prediction_body(
#     492     version,
#     493     input,
#     494     **params,
#     495 )
#     496 extras = _create_prediction_request_params(wait=wait)
# --> 497 resp = self._client._request("POST", "/v1/predictions", json=body, **extras)
#     499 return _json_to_prediction(self._client, resp.json())
#
# File d:\Resume-Projects\sellaiart-microservice\.venv\Lib\site-packages\replicate\client.py:89, in Client._request(self, method, path, **kwargs)
#      87 def _request(self, method: str, path: str, **kwargs) -> httpx.Response:
#      88     resp = self._client.request(method, path, **kwargs)
# ---> 89     _raise_for_status(resp)
#      91     return resp
#
# File d:\Resume-Projects\sellaiart-microservice\.venv\Lib\site-packages\replicate\client.py:393, in _raise_for_status(resp)
#     391 def _raise_for_status(resp: httpx.Response) -> None:
#     392     if 400 <= resp.status_code < 600:
# --> 393         raise ReplicateError.from_response(resp)
#
# ReplicateError: ReplicateError Details:
# title: Unauthenticated
# status: 401
# detail: You did not pass an authentication token

# %%
import random
session_id = random.randint(1_000, 40_000)
for i, output in enumerate(responses):
    fname = f"{i}-{session_id}.jpg"
    outpath = GENERATED_DIR / fname
    with open(outpath, 'wb') as f:
        f.write(output.read())
